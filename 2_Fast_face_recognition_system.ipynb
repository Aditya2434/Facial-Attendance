# %% [markdown]
# # Face Face Recognition Sytem

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in e:\faceattendance\attendance_system\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in e:\faceattendance\attendance_system\lib\site-packages (from opencv-python) (2.1.1)

# %%
# !pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in e:\faceattendance\attendance_system\lib\site-packages (from opencv-contrib-python) (2.1.1)
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/45.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/45.5 MB 2.4 MB/s eta 0:00:19
#     --------------------------------------- 1.0/45.5 MB 2.8 MB/s eta 0:00:16
#    - -------------------------------------- 1.6/45.5 MB 2.1 MB/s eta 0:00:21
#    - -------------------------------------- 1.8/45.5 MB 1.9 MB/s eta 0:00:24
#    - -------------------------------------- 2.1/45.5 MB 1.7 MB/s eta 0:00:26
#    - -------------------------------------- 2.1/45.5 MB 1.7 MB/s eta 0:00:26
#    -- ------------------------------------- 2.4/45.5 MB 1.5 MB/s eta 0:00:29
#    -- ------------------------------------- 2.4/45.5 MB 1.5 MB/s eta 0:00:29
#    -- ------------------------------------- 2.6/45.5 MB 1.3 MB/s eta 0:00:34
#    -- ------------------------------------- 2.6/45.5 MB 1.3 MB/s eta 0:00:34
#    -- ------------------------------------- 2.6/45.5 MB 1.3 MB/s eta 0:00:34
#    -- ------------------------------------- 2.6/45.5 MB 1.3 MB/s eta 0:00:34
#    -- ------------------------------------- 2.9/45.5 MB 1.0 MB/s eta 0:00:42
#    -- ------------------------------------- 2.9/45.5 MB 1.0 MB/s eta 0:00:42
#    -- ------------------------------------- 2.9/45.5 MB 1.0 MB/s eta 0:00:42
#    -- ------------------------------------- 3.1/45.5 MB 913.7 kB/s eta 0:00:47
#    -- ------------------------------------- 3.1/45.5 MB 913.7 kB/s eta 0:00:47
#    -- ------------------------------------- 3.1/45.5 MB 913.7 kB/s eta 0:00:47
#    -- ------------------------------------- 3.4/45.5 MB 805.4 kB/s eta 0:00:53
#    -- ------------------------------------- 3.4/45.5 MB 805.4 kB/s eta 0:00:53
#    -- ------------------------------------- 3.4/45.5 MB 805.4 kB/s eta 0:00:53
#    -- ------------------------------------- 3.4/45.5 MB 805.4 kB/s eta 0:00:53
#    --- ------------------------------------ 3.7/45.5 MB 741.8 kB/s eta 0:00:57
#    --- ------------------------------------ 3.7/45.5 MB 741.8 kB/s eta 0:00:57
#    --- ------------------------------------ 3.7/45.5 MB 741.8 kB/s eta 0:00:57
#    --- ------------------------------------ 3.9/45.5 MB 686.8 kB/s eta 0:01:01
#    --- ------------------------------------ 3.9/45.5 MB 686.8 kB/s eta 0:01:01
#    --- ------------------------------------ 3.9/45.5 MB 686.8 kB/s eta 0:01:01
#    --- ------------------------------------ 3.9/45.5 MB 686.8 kB/s eta 0:01:01
#    --- ------------------------------------ 4.2/45.5 MB 640.3 kB/s eta 0:01:05
#    --- ------------------------------------ 4.2/45.5 MB 640.3 kB/s eta 0:01:05
#    --- ------------------------------------ 4.2/45.5 MB 640.3 kB/s eta 0:01:05
#    -------------------------------------- - 44.3/45.5 MB 336.6 kB/s eta 0:00:04
#    ---------------------------------------  44.6/45.5 MB 333.6 kB/s eta 0:00:03
#    ---------------------------------------  44.6/45.5 MB 333.6 kB/s eta 0:00:03
#    ---------------------------------------  44.6/45.5 MB 333.6 kB/s eta 0:00:03
#    ---------------------------------------  44.8/45.5 MB 332.6 kB/s eta 0:00:03
#    ---------------------------------------  44.8/45.5 MB 332.6 kB/s eta 0:00:03
#    ---------------------------------------  44.8/45.5 MB 332.6 kB/s eta 0:00:03
#    ---------------------------------------  44.8/45.5 MB 332.6 kB/s eta 0:00:03
#    ---------------------------------------  44.8/45.5 MB 332.6 kB/s eta 0:00:03
#    ---------------------------------------  45.1/45.5 MB 338.8 kB/s eta 0:00:02
#    ---------------------------------------  45.1/45.5 MB 338.8 kB/s eta 0:00:02
#    ---------------------------------------  45.1/45.5 MB 338.8 kB/s eta 0:00:02
#    ---------------------------------------  45.1/45.5 MB 338.8 kB/s eta 0:00:02
#    ---------------------------------------  45.1/45.5 MB 338.8 kB/s eta 0:00:02
#    ---------------------------------------  45.4/45.5 MB 337.7 kB/s eta 0:00:01
#    ---------------------------------------  45.4/45.5 MB 337.7 kB/s eta 0:00:01
#    ---------------------------------------  45.4/45.5 MB 337.7 kB/s eta 0:00:01
#    ---------------------------------------- 45.5/45.5 MB 337.2 kB/s eta 0:00:00
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.10.0.84

# %%
import os
import cv2
import numpy as np
import pandas as pd

from insightface.app import FaceAnalysis
# Out:
# E:\FaceAttendance\attendance_system\Lib\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# configure face analysis
faceapp = FaceAnalysis(name='buffalo_sc',
                       root='insightface_model',
                       providers=['CPUExecutionProvider'])

faceapp.prepare(ctx_id=0, det_size=(640,640), det_thresh=0.5)
# warning: don't set det_thresh < 0.3
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: insightface_model\models\buffalo_sc\det_500m.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: insightface_model\models\buffalo_sc\w600k_mbf.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
#faceapp.get()

# %% [markdown]
# #### Extract Facial Features and labels

# %%
import re # regular expression

# %%
def clean_name(string):
    # Allow only A-Z a-z
    string = re.sub(r'[^A-Za-z]',' ',string)
    string = string.title()
    return string

# %%
person_info = []
listdir = os.listdir(path='images')
for folder_name in listdir:
    role, name = folder_name.split('-')
    name = clean_name(name)
    role = clean_name(role)
    #print('Role =',role,end='\t')
    #print('Name =', name)
    
    # path of each image in respective folder
    img_files = os.listdir(path= f'images/{folder_name}')
    for file in img_files:
        path = f'./images/{folder_name}/{file}'
        # step-1: read the image
        img_arr = cv2.imread(path)      
        
        # step-2: get the info
        result = faceapp.get(img_arr,max_num=1) # return list
        
        if len(result) > 0:
            # step-3: extract facial embedding
            res = result[0]
            embedding = res['embedding']
            # step-4: save all info name, role, embedding in a list
            person_info.append([name, role, embedding])

# %%
dataframe = pd.DataFrame(person_info,columns=['Name','Role','Facial_Features'])
dataframe # store in redis
# Out:
#                   Name     Role  \
# 0       Angelina Jolie  Student
# 1       Angelina Jolie  Student
# 2       Angelina Jolie  Student
# 3       Angelina Jolie  Student
# 4       Angelina Jolie  Student
# 5       Angelina Jolie  Student
# 6       Angelina Jolie  Student
# 7       Angelina Jolie  Student
# 8       Angelina Jolie  Student
# 9       Angelina Jolie  Student
# 10         Chris Evans  Student
# 11         Chris Evans  Student
# 12         Chris Evans  Student
# 13         Chris Evans  Student
# 14         Chris Evans  Student
# 15         Chris Evans  Student
# 16         Chris Evans  Student
# 17         Chris Evans  Student
# 18         Chris Evans  Student
# 19         Chris Evans  Student
# 20  Scarlett Johansson  Student
# 21  Scarlett Johansson  Student
# 22  Scarlett Johansson  Student
# 23  Scarlett Johansson  Student
# 24  Scarlett Johansson  Student
# 25  Scarlett Johansson  Student
# 26  Scarlett Johansson  Student
# 27  Scarlett Johansson  Student
# 28  Scarlett Johansson  Student
# 29  Scarlett Johansson  Student
# 30        Barack Obama  Teacher
# 31        Barack Obama  Teacher
# 32        Barack Obama  Teacher
# 33        Barack Obama  Teacher
# 34        Barack Obama  Teacher
# 35        Barack Obama  Teacher
# 36        Barack Obama  Teacher
# 37        Barack Obama  Teacher
# 38        Barack Obama  Teacher
# 39        Barack Obama  Teacher
# 40      Morgan Freeman  Teacher
# 41      Morgan Freeman  Teacher
# 42      Morgan Freeman  Teacher
# 43      Morgan Freeman  Teacher
# 44      Morgan Freeman  Teacher
# 45      Morgan Freeman  Teacher
# 46      Morgan Freeman  Teacher
# 47      Morgan Freeman  Teacher
# 48      Morgan Freeman  Teacher
# 49      Morgan Freeman  Teacher
#
#                                       Facial_Features
# 0   [-0.840976, 1.6623008, -0.74578035, -2.1380825...
# 1   [0.09012403, -0.41691077, -0.37650695, 0.42401...
# 2   [0.86389494, 0.32952014, 0.05781859, -1.453824...
# 3   [1.661117, 1.1610861, -0.41079235, -2.6411536,...
# 4   [0.86431384, 0.9437617, 0.4265172, -1.1836909,...
# 5   [0.41049737, 1.1810867, -0.99572563, -1.401910...
# 6   [0.42300692, 2.0838692, 1.0644906, -2.273823, ...
# 7   [0.3944185, 0.8441229, -0.6154812, -2.104783, ...
# 8   [1.0931158, 1.1680498, -0.2896319, -2.0099528,...
# 9   [-0.6354263, 1.7897136, 0.59832734, -3.5500891...
# 10  [1.8046336, -2.3015988, -1.5814648, -1.1037462...
# 11  [1.7491673, -2.1218207, -0.15238187, -0.905725...
# 12  [0.44954255, -1.6314546, -0.95116156, -1.54259...
# 13  [0.85855025, -1.0998964, -0.7710619, -1.491809...
# 14  [-1.1621714, -0.68589664, -0.43853605, -2.8765...
# 15  [0.3535511, -0.6977062, -0.30065766, -1.911663...
# 16  [1.3115128, -2.0906687, -1.0403854, -1.7981217...
# 17  [0.97152996, -1.7576457, -1.3096507, -1.026109...
# 18  [0.59088683, -1.4150559, -0.6726382, -1.310897...
# 19  [0.27377754, -0.883474, -0.56312096, -0.63476,...
# 20  [0.15681784, -0.15273607, -1.1741788, 0.222695...
# 21  [0.99884915, -0.34662226, -1.6070874, -0.34372...
# 22  [0.4184228, -1.2317784, -1.1667099, 0.32194257...
# 23  [0.74071044, -0.21720777, -2.1699548, -0.38209...
# 24  [-0.29318032, -0.027690813, -3.063887, -0.0223...
# 25  [0.91002095, -0.7951273, -2.354409, 0.8837526,...
# 26  [0.5181948, -0.7066632, -1.5376583, 0.9514046,...
# 27  [-0.9705691, -0.09710637, -2.1181054, 1.342366...
# 28  [0.87921476, -0.588027, 0.08242196, 0.6541158,...
# 29  [-1.445327, -0.7217442, -1.7932162, 0.79556346...
# 30  [0.86778015, -0.2674594, 0.07078171, -0.144091...
# 31  [1.6967453, -0.9937477, -0.22407177, -1.750015...
# 32  [0.048964567, -0.49315178, -0.19480643, -1.122...
# 33  [0.72383004, -0.94424045, -0.08774108, -2.4048...
# 34  [0.5904315, 0.4352536, 0.3595047, -2.803945, -...
# 35  [0.33068785, -1.2782054, 0.4005087, -1.3586802...
# 36  [-0.065080054, 0.01565358, -0.85267746, -0.329...
# 37  [2.2775648, -1.3967811, 1.5635507, -1.4799635,...
# 38  [1.604953, -0.24349236, 0.36104548, 0.04073015...
# 39  [1.4112034, -0.41739964, -0.4473747, -1.443192...
# 40  [0.5249792, -0.5247493, -0.51566666, 0.8267964...
# 41  [0.79333264, -0.4821538, -1.7259705, 0.6513495...
# 42  [-0.1314773, 0.04087484, 0.62813395, 0.6833665...
# 43  [0.48716566, -0.47769946, -1.0032179, 1.276978...
# 44  [1.2917783, -0.9464054, -0.1353631, 1.0459716,...
# 45  [-0.27494574, -0.27522963, -0.8412495, 1.27991...
# 46  [0.7716731, -0.6371074, 0.1712926, 0.55135304,...
# 47  [1.2278078, -1.56427, 0.42995828, 0.9718561, -...
# 48  [-0.26044086, 0.020359337, -0.4196607, 1.67541...
# 49  [0.42438617, -1.3472492, -0.657595, 1.7241019,...

# %% [markdown]
# ## Inference

# %% [markdown]
# ![feature_ex.jpg](attachment:feature_ex.jpg)

# %% [markdown]
# #### step-1: read image

# %%
# read test image
img_test = cv2.imread('test_images/test_2.jpeg')
cv2.imshow('test image',img_test)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### step -2: Extract Feature

# %%
res_test = faceapp.get(img_test,max_num=0)
for i, rt in enumerate(res_test):
    print('current loop =',i)
    bbox = rt['bbox'].astype(int)
    score = int(rt['det_score']*100)
    embed_test = rt['embedding']
# Out:
# current loop = 0

# %%
# consider only one sample
len(embed_test)
# Out:
# 512

# %%
embed_test
# Out:
# array([-1.0794208 , -1.1068169 , -1.2358055 , -1.1184733 ,  1.6912835 ,
#         1.2587602 , -0.42545304,  1.2529421 ,  1.9019961 ,  1.1875618 ,
#        -2.2458298 ,  2.0359764 , -0.16769719,  0.5307629 ,  0.30050385,
#        -0.21242332,  0.30540988, -1.0245438 ,  0.23911111,  1.2249293 ,
#        -0.31456357, -1.1223117 ,  2.434485  ,  1.028548  ,  0.6132133 ,
#        -1.2184055 ,  1.4724448 , -0.37911248, -1.1318517 ,  1.2429032 ,
#         1.1630024 ,  0.4936406 ,  0.96875656,  0.03858541,  0.40804625,
#        -0.41315192,  0.0175181 ,  0.35681504,  0.91274536, -0.13435462,
#         0.2293132 , -1.057251  ,  0.8617715 ,  0.63238996, -0.62710845,
#        -1.8728763 , -0.87928194,  1.1218289 ,  0.539179  ,  0.96189874,
#        -0.00892982, -1.0843854 , -0.23545067, -0.7008668 , -1.5224992 ,
#         0.20674597, -0.44925874,  0.93119305,  1.0777595 , -2.0912306 ,
#         0.85571814, -0.8692684 ,  1.3713725 ,  0.87135136, -0.39878762,
#         1.0382841 , -0.00342023,  1.150425  , -0.84119666,  0.03170621,
#        -0.5426823 , -1.0531307 , -1.1586863 , -0.26374733,  0.33640856,
#        -2.2551205 , -0.4932674 , -0.0376454 ,  0.23594262, -0.03102928,
#         0.87827444,  0.67492753, -0.2025491 , -0.18196923,  0.19972259,
#        -0.45754933,  1.6048309 ,  0.19026561,  0.06499219,  1.1347313 ,
#         0.6342978 ,  1.1965535 , -0.4713784 ,  1.6729575 ,  1.1985319 ,
#         0.0519219 ,  1.2571034 ,  0.06338592,  0.30742994,  0.21583545,
#         0.02282131,  0.33632582,  0.00444224, -0.22221157, -0.08307451,
#         0.13153867,  1.8354304 ,  0.05383989, -0.17290853, -0.6640408 ,
#         0.2800306 ,  1.2362871 , -1.2588502 ,  1.8468266 , -0.45168245,
#        -0.03253618, -0.39902943,  0.6726371 , -1.0109618 ,  0.495156  ,
#        -1.3489293 , -0.60116   ,  0.03712404, -0.6319255 ,  0.14831959,
#        -0.477364  ,  0.36743307, -0.06023616,  1.4165711 , -0.06309438,
#        -0.76162016, -0.01509392,  0.91653156,  1.0660012 , -1.4544392 ,
#        -1.1711987 , -0.46073997, -0.79773605, -0.83444524,  0.01974517,
#         0.18770511, -1.268563  ], dtype=float32)

# %% [markdown]
# #### Algorithm

# %% [markdown]
# ![algorithm.svg](attachment:algorithm.svg)

# %%
X_list =  dataframe['Facial_Features'].tolist()
X = np.asarray(X_list)

# %%
X.shape
# Out:
# (50, 512)

# %%
from sklearn.metrics import pairwise

# %%
y = embed_test.reshape(1,512) # 1 x 512

equlidean_distance = pairwise.euclidean_distances(X,y)
manhattan_distance = pairwise.manhattan_distances(X,y)
cosine_similar = pairwise.cosine_similarity(X,y)

# %%
data_search = dataframe.copy()
data_search['equlidean'] = equlidean_distance
data_search['manhattan'] = manhattan_distance
data_search['cosine'] = cosine_similar

# %%
data_search.head(2)
# Out:
#              Name     Role                                    Facial_Features  \
# 0  Angelina Jolie  Student  [-0.840976, 1.6623008, -0.74578035, -2.1380825...
# 1  Angelina Jolie  Student  [0.09012403, -0.41691077, -0.37650695, 0.42401...
#
#    equlidean   manhattan    cosine
# 0  30.831608  550.446652 -0.011336
# 1  30.680958  555.258289  0.018317

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,16))
plt.subplot(3,1,1)
plt.plot(data_search['equlidean'],)
plt.xticks(ticks=list(range(len(data_search['equlidean']))),
           labels=data_search['Name'],rotation=90)
plt.xlabel('Name of the Person')
plt.ylabel('Equlidean')
plt.title('Equlidean Distance')
plt.grid()

plt.subplot(3,1,2)
plt.plot(data_search['manhattan'],)
plt.xticks(ticks=list(range(len(data_search['manhattan']))),
           labels=data_search['Name'],rotation=90)
plt.xlabel('Name of the Person')
plt.ylabel('manhattan')
plt.title('Manhattan Distance')
plt.grid()


plt.subplot(3,1,3)
plt.plot(data_search['cosine'],)
plt.xticks(ticks=list(range(len(data_search['cosine']))),
           labels=data_search['Name'],rotation=90)
plt.xlabel('Name of the Person')
plt.ylabel('cosine')
plt.title('Cosine Similarity')
plt.grid()


plt.show()

# %% [markdown]
# ### Identify the Person using Equlidean Distance

# %%
d_eq_optimal = 25

# %%
datafilter = data_search.query(f'equlidean < {d_eq_optimal}')
datafilter.reset_index(drop=True,inplace=True)

if len(datafilter) > 0:
    argmin = datafilter['equlidean'].argmin()
    name , role = datafilter.loc[argmin][['Name','Role']]
    
else:
    name = 'Unknown'
    role = 'Unknown'

# %%
print(name, role)
# Out:
# Chris Evans Student

# %% [markdown]
# ### Identify the Person using Manhattan Distance

# %%
d_man_optimal = 450

# %%
datafilter = data_search.query(f'manhattan < {d_man_optimal}')
datafilter.reset_index(drop=True,inplace=True)

if len(datafilter) > 0:
    argmin = datafilter['manhattan'].argmin()
    name_man , role_man = datafilter.loc[argmin][['Name','Role']]
    
else:
    name_man = 'Unknown'
    role_man = 'Unknown'

# %%
print(name, role)
# Out:
# Chris Evans Student

# %% [markdown]
# ### Identify the Person using Cosine Similarity

# %%
S_opt = 0.4

# %%
datafilter = data_search.query(f'cosine > {S_opt}')
datafilter.reset_index(drop=True,inplace=True)

if len(datafilter) > 0:
    argmax = datafilter['cosine'].argmax()
    name_cos , role_cos = datafilter.loc[argmax][['Name','Role']]
    
else:
    name_cos = 'Unknown'
    role_cos = 'Unknown'

# %%
print(name_cos, role_cos)
# Out:
# Chris Evans Student

# %%
datafilter
# Out:
#           Name     Role                                    Facial_Features  \
# 0  Chris Evans  Student  [1.7491673, -2.1218207, -0.15238187, -0.905725...
# 1  Chris Evans  Student  [0.44954255, -1.6314546, -0.95116156, -1.54259...
# 2  Chris Evans  Student  [0.85855025, -1.0998964, -0.7710619, -1.491809...
# 3  Chris Evans  Student  [0.3535511, -0.6977062, -0.30065766, -1.911663...
# 4  Chris Evans  Student  [1.3115128, -2.0906687, -1.0403854, -1.7981217...
# 5  Chris Evans  Student  [0.59088683, -1.4150559, -0.6726382, -1.310897...
#
#    equlidean   manhattan    cosine
# 0  25.515486  450.687724  0.423367
# 1  24.786526  450.057994  0.430162
# 2  23.976940  426.412996  0.458632
# 3  23.396654  427.903388  0.460120
# 4  23.065950  426.244138  0.466912
# 5  22.336002  406.118973  0.495197

# %% [markdown]
# ### Identify Multiple Person in an Image

# %%
def ml_search_algorithm(dataframe,feature_column,test_vector,
                        name_role=['Name','Role'],thresh=0.5):
    """
    cosine similarity base search algorithm
    """
    # step-1: take the dataframe (collection of data)
    dataframe = dataframe.copy()
    # step-2: Index face embeding from the dataframe and convert into array
    X_list = dataframe[feature_column].tolist()
    x = np.asarray(X_list)
    
    # step-3: Cal. cosine similarity
    similar = pairwise.cosine_similarity(x,test_vector.reshape(1,-1))
    similar_arr = np.array(similar).flatten()
    dataframe['cosine'] = similar_arr

    # step-4: filter the data
    data_filter = dataframe.query(f'cosine >= {thresh}')
    if len(data_filter) > 0:
        # step-5: get the person name
        data_filter.reset_index(drop=True,inplace=True)
        argmax = data_filter['cosine'].argmax()
        person_name, person_role = data_filter.loc[argmax][name_role]
        
    else:
        person_name = 'Unknown'
        person_role = 'Unknown'
        
    return person_name, person_role

# %%
test_image = cv2.imread('test_images/test_10.jpg')
cv2.imshow('test image',test_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# step-1: take the test image and apply to insight face
results = faceapp.get(test_image)
test_copy = test_image.copy()
# step-2: use for loop and extract each embedding and pass to ml_search_algorithm

for res in results:
    x1, y1, x2, y2 = res['bbox'].astype(int)
    embeddings = res['embedding']
    person_name, person_role = ml_search_algorithm(dataframe,
                                                   'Facial_Features',
                                                   test_vector=embeddings,
                                                   name_role=['Name','Role'],
                                                   thresh=0.5)
    if person_name == 'Unknown':
        color =(0,0,255) # bgr
    else:
        color = (0,255,0)
        
        
    cv2.rectangle(test_copy,(x1,y1),(x2,y2),color)
    
    text_gen = person_name
    cv2.putText(test_copy,text_gen,(x1,y1),cv2.FONT_HERSHEY_DUPLEX,0.7,color,2)
    
    
cv2.imshow('test image',test_copy)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### Compressing my dataset

# %%
dataframe_compress = dataframe.groupby(by=['Name','Role']).mean()
dataframe_compress.reset_index(inplace=True)
dataframe_compress
# Out:
#                  Name     Role  \
# 0      Angelina Jolie  Student
# 1        Barack Obama  Teacher
# 2         Chris Evans  Student
# 3      Morgan Freeman  Teacher
# 4  Scarlett Johansson  Student
#
#                                      Facial_Features
# 0  [0.43240861892700194, 1.0746600151062011, -0.1...
# 1  [0.9487079620361328, -0.558357048034668, 0.094...
# 2  [0.7200980663299561, -1.468521785736084, -0.77...
# 3  [0.48542585372924807, -0.6193629741668701, -0....
# 4  [0.1913154363632202, -0.48847031593322754, -1....

# %% [markdown]
# #### convert dataframe into array and save in numpy zip format

# %%
xvalues = dataframe_compress.values

# %%
col_name = np.array(dataframe_compress.columns)
col_name
# Out:
# array(['Name', 'Role', 'Facial_Features'], dtype=object)

# %%
np.savez('dataframe_students_teacher.npz',xvalues,col_name)

# %%
# load the numpy zip
file_np = np.load('dataframe_students_teacher.npz',allow_pickle=True)
file_np.files
# Out:
# ['arr_0', 'arr_1']

# %%
pd.DataFrame(file_np['arr_0'],columns=file_np['arr_1'])
# Out:
#                  Name     Role  \
# 0      Angelina Jolie  Student
# 1        Barack Obama  Teacher
# 2         Chris Evans  Student
# 3      Morgan Freeman  Teacher
# 4  Scarlett Johansson  Student
#
#                                      Facial_Features
# 0  [0.43240861892700194, 1.0746600151062011, -0.1...
# 1  [0.9487079620361328, -0.558357048034668, 0.094...
# 2  [0.7200980663299561, -1.468521785736084, -0.77...
# 3  [0.48542585372924807, -0.6193629741668701, -0....
# 4  [0.1913154363632202, -0.48847031593322754, -1....

# %% [markdown]
# ### [END](https://www.udemy.com/user/freeai-space/)
# ---
